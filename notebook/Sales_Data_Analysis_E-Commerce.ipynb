# %% [markdown]
# # Sales Data Analysis(E- Commerce)

# %% [markdown]
# This project is focused on analyzing an E-commerce business. The dataset includes order ID, product information, customer details, quantity, price, and location. The key objectives of the analysis are to determine the most sold products, identify the month with the highest sales volume, and pinpoint the city with the highest sales.
# The data is stored in the feather format, a lightweight binary file format designed for efficient data storage and exchange between programming languages, especially for data analysis and machine learning workflows. To work with feather files, the pyarrow package needs to be installed.
# The use of "r" denotes row strings, enabling Pandas to read the file efficiently.
# As part of the project, rows with missing data will be dropped, and duplicates have already been eliminated.

# %% [markdown]
# This project aims to answer several key questions related to the E-commerce business analysis:
#
#    - What is the best month in terms of sales?
#    - Which city has the highest sales volume?
#    - Which product generates the highest revenue for the business?
#    - What products are most frequently purchased by clients?
#    - Which products are commonly sold together?

# %% [markdown]
# Project Parts:
#
#    - Data Extraction:
#         Extracting the necessary data for analysis from the E-commerce business dataset.
#
#    - Data Transformation:
#         - Searching for missing data in the dataset.
#         - Dropping the rows with missing data to ensure data completeness.
#         - Identifying and searching for any duplicate entries in the dataset.
#         - Dropping duplicate entries to ensure data accuracy.
#
#    - Monthly Sales Analysis:
#         Analyzing the sales data on a monthly basis to identify patterns and trends.
#
#    - Month Extraction:
#         Extracting the month from the available dates in the dataset.
#
#    - Data Type Conversion:
#         Converting certain data types, if needed, to facilitate analysis and visualization.
#
#    - Answering Questions through Data Visualization:
#         Utilizing data visualization techniques to answer specific questions related to the E-commerce business.
#
#
# By following these project parts, we can effectively extract and transform the data, analyze monthly sales, extract relevant information such as the month, convert data types if required, and provide answers to specific questions through the visualization of the data. This approach enables a comprehensive analysis of the E-commerce business dataset, leading to valuable insights and informed decision-making.

# %%
import pandas as pd 
import numpy as np 
import matplotlib.pyplot as plt 
import seaborn as sns 
import warnings
from warnings import filterwarnings
filterwarnings('ignore')

# %%
# !pip install pyarrow
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
# [notice] A new release of pip is available: 23.2 -> 23.2.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
all_data=pd.read_feather (r"C:/Users/maiba/Desktop/Projects GitHub/Sales/Sales_data.ftr")
all_data
# Out:
#        Order ID                     Product Quantity Ordered Price Each  \
# 0        176558        USB-C Charging Cable                2      11.95
# 1          None                        None             None       None
# 2        176559  Bose SoundSport Headphones                1      99.99
# 3        176560                Google Phone                1        600
# 4        176560            Wired Headphones                1      11.99
# ...         ...                         ...              ...        ...
# 186845   259353      AAA Batteries (4-pack)                3       2.99
# 186846   259354                      iPhone                1        700
# 186847   259355                      iPhone                1        700
# 186848   259356      34in Ultrawide Monitor                1     379.99
# 186849   259357        USB-C Charging Cable                1      11.95
#
#             Order Date                         Purchase Address
# ...

# %%
all_data.isnull().sum()
# Out:
# Order ID            545
# Product             545
# Quantity Ordered    545
# Price Each          545
# Order Date          545
# Purchase Address    545
# dtype: int64

# %%
all_data.dropna()
# Out:
#        Order ID                     Product Quantity Ordered Price Each  \
# 0        176558        USB-C Charging Cable                2      11.95
# 2        176559  Bose SoundSport Headphones                1      99.99
# 3        176560                Google Phone                1        600
# 4        176560            Wired Headphones                1      11.99
# 5        176561            Wired Headphones                1      11.99
# ...         ...                         ...              ...        ...
# 186845   259353      AAA Batteries (4-pack)                3       2.99
# 186846   259354                      iPhone                1        700
# 186847   259355                      iPhone                1        700
# 186848   259356      34in Ultrawide Monitor                1     379.99
# 186849   259357        USB-C Charging Cable                1      11.95
#
#             Order Date                         Purchase Address
# ...

# %%
all_data=all_data.dropna()

# %%
all_data.isnull().sum()
# Out:
# Order ID            0
# Product             0
# Quantity Ordered    0
# Price Each          0
# Order Date          0
# Purchase Address    0
# dtype: int64

# %%
all_data.duplicated() ##this will show a serise
# Out:
# 0         False
# 2         False
# 3         False
# 4         False
# 5         False
#           ...
# 186845    False
# 186846    False
# 186847    False
# 186848    False
# 186849    False
# Length: 186305, dtype: bool

# %%
all_data[all_data.duplicated()]
# Out:
#         Order ID                     Product  Quantity Ordered  Price Each  \
# 31        176585  Bose SoundSport Headphones                 1       99.99
# 1149    Order ID                     Product  Quantity Ordered  Price Each
# 1155    Order ID                     Product  Quantity Ordered  Price Each
# 1302      177795    Apple Airpods Headphones                 1         150
# 1684      178158        USB-C Charging Cable                 1       11.95
# ...          ...                         ...               ...         ...
# 186563  Order ID                     Product  Quantity Ordered  Price Each
# 186632  Order ID                     Product  Quantity Ordered  Price Each
# 186738  Order ID                     Product  Quantity Ordered  Price Each
# 186782    259296    Apple Airpods Headphones                 1         150
# 186785    259297    Lightning Charging Cable                 1       14.95
#
#             Order Date                        Purchase Address
# ...

# %%
all_data.duplicated().sum()
# Out:
# 618

# %%
all_data=all_data.drop_duplicates()

# %%
all_data.shape
# Out:
# (185687, 6)

# %%
##which is the best month sales?

# %%
all_data.head(2)
# Out:
#   Order ID                     Product Quantity Ordered Price Each  \
# 0   176558        USB-C Charging Cable                2      11.95
# 2   176559  Bose SoundSport Headphones                1      99.99
#
#        Order Date                   Purchase Address
# 0  04/19/19 08:46       917 1st St, Dallas, TX 75001
# 2  04/07/19 22:30  682 Chestnut St, Boston, MA 02215

# %%
all_data['Order Date']
# Out:
# 0         04/19/19 08:46
# 2         04/07/19 22:30
# 3         04/12/19 14:38
# 4         04/12/19 14:38
# 5         04/30/19 09:27
#                ...
# 186845    09/17/19 20:56
# 186846    09/01/19 16:00
# 186847    09/23/19 07:39
# 186848    09/19/19 17:30
# 186849    09/30/19 00:18
# Name: Order Date, Length: 185687, dtype: object

# %%
all_data['Order Date'][0] ##to get the date for index zero
# Out:
# '04/19/19 08:46'

# %%
'04/19/19 08:46'.split(' ') ## spliting the date and the time Considering space as a separator
# Out:
# ['04/19/19', '08:46']

# %%
'04/19/19 08:46'.split(' ')[0] ##I need to access the first element.#Hence I can mention the index of the list, 
#which is zero because indexes of the list initialized from zero.
#If I'm going to execute it, you will end up getting the entire date,
# Out:
# '04/19/19'

# %%
##So let's say I need I need this month only.

#Then I can again call this split.

#This time I will say my separator will be the slash.

'04/19/19 08:46'.split(' ')[0].split('/')
# Out:
# ['04', '19', '19']

# %%
###another way or to make it simple
all_data['Order Date'][0].split('/')[0]
# Out:
# '04'

# %%
###create def 
def return_month(x):
    return x.split('/')[0]

# %%
all_data['Order Date'].apply(return_month)
# Out:
# 0         04
# 2         04
# 3         04
# 4         04
# 5         04
#           ..
# 186845    09
# 186846    09
# 186847    09
# 186848    09
# 186849    09
# Name: Order Date, Length: 185687, dtype: object

# %%
##creat new column 
all_data['Month']=all_data['Order Date'].apply(return_month)

# %%
all_data.dtypes
# Out:
# Order ID            object
# Product             object
# Quantity Ordered    object
# Price Each          object
# Order Date          object
# Purchase Address    object
# Month               object
# dtype: object

# %%
##convert Month from object to int 
all_data['Month'].astype(int)
##this error shows that there is a value in month called 
#order date so we will look at the unique values
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[25], line 2
#       1 ##convert Month from object to int
# ----> 2 all_data['Month'].astype(int)
#       3 ##this error shows that there is a value in month called
#       4 #order date so we will look at the unique values
#
# File ~\AppData\Roaming\Python\Python311\site-packages\pandas\core\generic.py:6324, in NDFrame.astype(self, dtype, copy, errors)
#    6317     results = [
#    6318         self.iloc[:, i].astype(dtype, copy=copy)
#    6319         for i in range(len(self.columns))
#    6320     ]
#    6322 else:
#    6323     # else, only a single dtype is given
# -> 6324     new_data = self._mgr.astype(dtype=dtype, copy=copy, errors=errors)
#    6325     return self._constructor(new_data).__finalize__(self, method="astype")
#    6327 # GH 33113: handle empty frame or series
#
# ...

# %%
all_data['Month'].unique()
# Out:
# array(['04', '05', 'Order Date', '08', '09', '12', '01', '02', '03', '07',
#        '06', '11', '10'], dtype=object)

# %%
filter1=all_data['Month'] == 'Order Date'

# %%
(all_data['Month'] == 'Order Date').sum()
##the number of values = order date
# Out:
# 1

# %%
all_data[filter1]
# Out:
#      Order ID  Product  Quantity Ordered  Price Each  Order Date  \
# 519  Order ID  Product  Quantity Ordered  Price Each  Order Date
#
#      Purchase Address       Month
# 519  Purchase Address  Order Date

# %%
all_data[~filter1] ## this will get you the data frame without
#the order date value
# Out:
#        Order ID                     Product Quantity Ordered Price Each  \
# 0        176558        USB-C Charging Cable                2      11.95
# 2        176559  Bose SoundSport Headphones                1      99.99
# 3        176560                Google Phone                1        600
# 4        176560            Wired Headphones                1      11.99
# 5        176561            Wired Headphones                1      11.99
# ...         ...                         ...              ...        ...
# 186845   259353      AAA Batteries (4-pack)                3       2.99
# 186846   259354                      iPhone                1        700
# 186847   259355                      iPhone                1        700
# 186848   259356      34in Ultrawide Monitor                1     379.99
# 186849   259357        USB-C Charging Cable                1      11.95
#
#             Order Date                         Purchase Address Month
# ...

# %%
#update the data frame
all_data=all_data[~filter1]

# %%
all_data.shape
# Out:
# (185686, 7)

# %%
### lets back to the code wich gave error before 
##convert Month from object to int 
##with keep updating the dataframe 
all_data['Month'] = all_data['Month'].astype(int)

# %%
all_data.dtypes
# Out:
# Order ID            object
# Product             object
# Quantity Ordered    object
# Price Each          object
# Order Date          object
# Purchase Address    object
# Month                int32
# dtype: object

# %%
all_data['Quantity Ordered'] = all_data['Quantity Ordered'].astype(int)
all_data['Price Each'] = all_data['Price Each'].astype(float)

# %%
all_data.dtypes
# Out:
# Order ID             object
# Product              object
# Quantity Ordered      int32
# Price Each          float64
# Order Date           object
# Purchase Address     object
# Month                 int32
# dtype: object

# %%
all_data['Sales']=all_data['Quantity Ordered']*all_data['Price Each']

# %%
all_data['Sales']
# Out:
# 0          23.90
# 2          99.99
# 3         600.00
# 4          11.99
# 5          11.99
#            ...
# 186845      8.97
# 186846    700.00
# 186847    700.00
# 186848    379.99
# 186849     11.95
# Name: Sales, Length: 185686, dtype: float64

# %%
all_data.groupby(['Month'])['Sales'].sum()
# Out:
# Month
# 1     1821413.16
# 2     2200078.08
# 3     2804973.35
# 4     3389217.98
# 5     3150616.23
# 6     2576280.15
# 7     2646461.32
# 8     2241083.37
# 9     2094465.69
# 10    3734777.86
# 11    3197875.05
# 12    4608295.70
# Name: Sales, dtype: float64

# %%
all_data.groupby(['Month'])['Sales'].sum().plot(kind='bar')
# Out:
# <Axes: xlabel='Month'>

# %%
##which city has the max order?
all_data.head()
# Out:
#   Order ID                     Product  Quantity Ordered  Price Each  \
# 0   176558        USB-C Charging Cable                 2       11.95
# 2   176559  Bose SoundSport Headphones                 1       99.99
# 3   176560                Google Phone                 1      600.00
# 4   176560            Wired Headphones                 1       11.99
# 5   176561            Wired Headphones                 1       11.99
#
#        Order Date                      Purchase Address  Month   Sales
# 0  04/19/19 08:46          917 1st St, Dallas, TX 75001      4   23.90
# 2  04/07/19 22:30     682 Chestnut St, Boston, MA 02215      4   99.99
# 3  04/12/19 14:38  669 Spruce St, Los Angeles, CA 90001      4  600.00
# 4  04/12/19 14:38  669 Spruce St, Los Angeles, CA 90001      4   11.99
# 5  04/30/19 09:27     333 8th St, Los Angeles, CA 90001      4   11.99

# %%
all_data['Purchase Address']
# Out:
# 0                    917 1st St, Dallas, TX 75001
# 2               682 Chestnut St, Boston, MA 02215
# 3            669 Spruce St, Los Angeles, CA 90001
# 4            669 Spruce St, Los Angeles, CA 90001
# 5               333 8th St, Los Angeles, CA 90001
#                            ...
# 186845     840 Highland St, Los Angeles, CA 90001
# 186846    216 Dogwood St, San Francisco, CA 94016
# 186847       220 12th St, San Francisco, CA 94016
# 186848     511 Forest St, San Francisco, CA 94016
# 186849     250 Meadow St, San Francisco, CA 94016
# Name: Purchase Address, Length: 185686, dtype: object

# %%
all_data['Purchase Address'][0]
# Out:
# '917 1st St, Dallas, TX 75001'

# %%
all_data['Purchase Address'][0].split(',')
# Out:
# ['917 1st St', ' Dallas', ' TX 75001']

# %%
all_data['Purchase Address'][0].split(',')[1]
# Out:
# ' Dallas'

# %%
def return_city(x):
    return x.split(',')

# %%
#all_data['City']=all_data['Purchase Address'].apply(return_city)

# %%
#all_data.head()

# %%
all_data.head()
# Out:
#   Order ID                     Product  Quantity Ordered  Price Each  \
# 0   176558        USB-C Charging Cable                 2       11.95
# 2   176559  Bose SoundSport Headphones                 1       99.99
# 3   176560                Google Phone                 1      600.00
# 4   176560            Wired Headphones                 1       11.99
# 5   176561            Wired Headphones                 1       11.99
#
#        Order Date                      Purchase Address  Month   Sales
# 0  04/19/19 08:46          917 1st St, Dallas, TX 75001      4   23.90
# 2  04/07/19 22:30     682 Chestnut St, Boston, MA 02215      4   99.99
# 3  04/12/19 14:38  669 Spruce St, Los Angeles, CA 90001      4  600.00
# 4  04/12/19 14:38  669 Spruce St, Los Angeles, CA 90001      4   11.99
# 5  04/30/19 09:27     333 8th St, Los Angeles, CA 90001      4   11.99

# %%
##We have a package which is a Pandas, which we are using extensively
#in this pandas, whatever the string #If I say as dot str, it means I'm 
#going to access all the string functions and let's say I'm going#Because at
#the second index in each of the list, let's say in this list, right In
#this list at second index, you will end up getting your city name.

#I can say as dot str, I am again going to access all the string functions 
#and this time I will say

#just get back the data of first index of the list.

#to access the split function where my separator is comma.

#functions you have, you can access all those string function using your dot 
#str accessor.

all_data['City']=all_data['Purchase Address'].str.split(',').str.get(1)

# %%
all_data.head(2)
# Out:
#   Order ID                     Product  Quantity Ordered  Price Each  \
# 0   176558        USB-C Charging Cable                 2       11.95
# 2   176559  Bose SoundSport Headphones                 1       99.99
#
#        Order Date                   Purchase Address  Month  Sales     City
# 0  04/19/19 08:46       917 1st St, Dallas, TX 75001      4  23.90   Dallas
# 2  04/07/19 22:30  682 Chestnut St, Boston, MA 02215      4  99.99   Boston

# %%
all_data.groupby(['City'])['Sales'].sum().sort_values(ascending=False)
# Out:
# City
#  San Francisco    8254743.55
#  Los Angeles      5448304.28
#  New York City    4661867.14
#  Boston           3658627.65
#  Atlanta          2794199.07
#  Dallas           2765373.96
#  Seattle          2745046.02
#  Portland         2319331.94
#  Austin           1818044.33
# Name: Sales, dtype: float64

# %%
all_data.groupby(['City'])['Sales'].sum().plot(kind='bar')
# Out:
# <Axes: xlabel='City'>

# %%
all_data.groupby(['City'])['Sales'].sum().sort_values(ascending=False).plot(kind='pie', autopct ='%1.0f%%')
# Out:
# <Axes: ylabel='Sales'>

# %%
pd.value_counts(all_data['City'])
# Out:
# City
#  San Francisco    44662
#  Los Angeles      29564
#  New York City    24847
#  Boston           19901
#  Atlanta          14863
#  Dallas           14797
#  Seattle          14713
#  Portland         12449
#  Austin            9890
# Name: count, dtype: int64

# %%
pd.value_counts(all_data['City']).plot(kind='bar')
# Out:
# <Axes: xlabel='City'>

# %%
all_data.head(2)
# Out:
#   Order ID                     Product  Quantity Ordered  Price Each  \
# 0   176558        USB-C Charging Cable                 2       11.95
# 2   176559  Bose SoundSport Headphones                 1       99.99
#
#        Order Date                   Purchase Address  Month  Sales     City
# 0  04/19/19 08:46       917 1st St, Dallas, TX 75001      4  23.90   Dallas
# 2  04/07/19 22:30  682 Chestnut St, Boston, MA 02215      4  99.99   Boston

# %%
all_data['Product'].value_counts()
# Out:
# Product
# USB-C Charging Cable          21859
# Lightning Charging Cable      21610
# AAA Batteries (4-pack)        20612
# AA Batteries (4-pack)         20558
# Wired Headphones              18849
# Apple Airpods Headphones      15525
# Bose SoundSport Headphones    13298
# 27in FHD Monitor               7498
# iPhone                         6840
# 27in 4K Gaming Monitor         6225
# 34in Ultrawide Monitor         6174
# Google Phone                   5522
# Flatscreen TV                  4794
# Macbook Pro Laptop             4721
# ThinkPad Laptop                4126
# 20in Monitor                   4098
# Vareebadd Phone                2065
# LG Washing Machine              666
# LG Dryer                        646
# Name: count, dtype: int64

# %%
all_data.columns
# Out:
# Index(['Order ID', 'Product', 'Quantity Ordered', 'Price Each', 'Order Date',
#        'Purchase Address', 'Month', 'Sales', 'City'],
#       dtype='object')

# %%
count_df=all_data.groupby(['Product']).agg({'Quantity Ordered':'sum', 'Price Each':'mean'})

# %%
count_df
# Out:
#                             Quantity Ordered  Price Each
# Product
# 20in Monitor                            4126      109.99
# 27in 4K Gaming Monitor                  6239      389.99
# 27in FHD Monitor                        7541      149.99
# 34in Ultrawide Monitor                  6192      379.99
# AA Batteries (4-pack)                  27615        3.84
# AAA Batteries (4-pack)                 30986        2.99
# Apple Airpods Headphones               15637      150.00
# Bose SoundSport Headphones             13430       99.99
# Flatscreen TV                           4813      300.00
# Google Phone                            5529      600.00
# LG Dryer                                 646      600.00
# LG Washing Machine                       666      600.00
# Lightning Charging Cable               23169       14.95
# Macbook Pro Laptop                      4725     1700.00
# ThinkPad Laptop                         4128      999.99
# ...

# %%
count_df=count_df.reset_index()
count_df
# Out:
#     index                     Product  Quantity Ordered  Price Each
# 0       0                20in Monitor              4126      109.99
# 1       1      27in 4K Gaming Monitor              6239      389.99
# 2       2            27in FHD Monitor              7541      149.99
# 3       3      34in Ultrawide Monitor              6192      379.99
# 4       4       AA Batteries (4-pack)             27615        3.84
# 5       5      AAA Batteries (4-pack)             30986        2.99
# 6       6    Apple Airpods Headphones             15637      150.00
# 7       7  Bose SoundSport Headphones             13430       99.99
# 8       8               Flatscreen TV              4813      300.00
# 9       9                Google Phone              5529      600.00
# 10     10                    LG Dryer               646      600.00
# 11     11          LG Washing Machine               666      600.00
# 12     12    Lightning Charging Cable             23169       14.95
# ...

# %%
Products=count_df['Product'].values
Products
# Out:
# array(['20in Monitor', '27in 4K Gaming Monitor', '27in FHD Monitor',
#        '34in Ultrawide Monitor', 'AA Batteries (4-pack)',
#        'AAA Batteries (4-pack)', 'Apple Airpods Headphones',
#        'Bose SoundSport Headphones', 'Flatscreen TV', 'Google Phone',
#        'LG Dryer', 'LG Washing Machine', 'Lightning Charging Cable',
#        'Macbook Pro Laptop', 'ThinkPad Laptop', 'USB-C Charging Cable',
#        'Vareebadd Phone', 'Wired Headphones', 'iPhone'], dtype=object)

# %%
fig , ax1 =plt.subplots()
ax2=ax1.twinx()
ax1.bar(count_df['Product'] , count_df['Quantity Ordered'] , color= 'orange')
ax2.plot(count_df['Product'] , count_df['Price Each'], color='black')
ax1.set_xticklabels(Products, rotation='vertical')

ax1.set_ylabel('Order Count')
ax2.set_ylabel('Avg price')
# Out:
# Text(0, 0.5, 'Avg price')

# %%
all_data['Product'].value_counts()[0:5]
# Out:
# Product
# USB-C Charging Cable        21859
# Lightning Charging Cable    21610
# AAA Batteries (4-pack)      20612
# AA Batteries (4-pack)       20558
# Wired Headphones            18849
# Name: count, dtype: int64

# %%
most_sold_products=all_data['Product'].value_counts()[0:5].index
most_sold_products
# Out:
# Index(['USB-C Charging Cable', 'Lightning Charging Cable',
#        'AAA Batteries (4-pack)', 'AA Batteries (4-pack)', 'Wired Headphones'],
#       dtype='object', name='Product')

# %%
all_data['Product'].isin(most_sold_products)
# Out:
# 0          True
# 2         False
# 3         False
# 4          True
# 5          True
#           ...
# 186845     True
# 186846    False
# 186847    False
# 186848    False
# 186849     True
# Name: Product, Length: 185686, dtype: bool

# %%
most_sold_products_df=all_data[all_data['Product'].isin(most_sold_products)] 
### creating new df contain the data of only the top 5 sold products

# %%
most_sold_products_df
# Out:
#        Order ID                 Product  Quantity Ordered  Price Each  \
# 0        176558    USB-C Charging Cable                 2       11.95
# 4        176560        Wired Headphones                 1       11.99
# 5        176561        Wired Headphones                 1       11.99
# 6        176562    USB-C Charging Cable                 1       11.95
# 8        176564    USB-C Charging Cable                 1       11.95
# ...         ...                     ...               ...         ...
# 186840   259349  AAA Batteries (4-pack)                 1        2.99
# 186842   259350    USB-C Charging Cable                 1       11.95
# 186844   259352    USB-C Charging Cable                 1       11.95
# 186845   259353  AAA Batteries (4-pack)                 3        2.99
# 186849   259357    USB-C Charging Cable                 1       11.95
#
#             Order Date                        Purchase Address  Month  Sales  \
# ...

# %%
##creatin pivot table 
most_sold_products_df.groupby(['Month', 'Product']).size()
##size function is used to compute the number of occurrences for each combination of 'Month' and 
##'Product' in the most_sold_products_df dataframe.
# Out:
# Month  Product
# 1      AA Batteries (4-pack)       1037
#        AAA Batteries (4-pack)      1084
#        Lightning Charging Cable    1069
#        USB-C Charging Cable        1171
#        Wired Headphones            1004
# 2      AA Batteries (4-pack)       1274
#        AAA Batteries (4-pack)      1320
#        Lightning Charging Cable    1393
#        USB-C Charging Cable        1511
#        Wired Headphones            1179
# 3      AA Batteries (4-pack)       1672
#        AAA Batteries (4-pack)      1645
#        Lightning Charging Cable    1749
#        USB-C Charging Cable        1766
#        Wired Headphones            1512
# 4      AA Batteries (4-pack)       2062
#        AAA Batteries (4-pack)      1988
#        Lightning Charging Cable    2197
#        USB-C Charging Cable        2074
#        Wired Headphones            1888
# 5      AA Batteries (4-pack)       1821
#        AAA Batteries (4-pack)      1888
#        Lightning Charging Cable    1929
# ...

# %% [markdown]
# The unstack() function is used to reshape the hierarchical index created by the groupby() operation into a more tabular format.
#
# In the code most_sold_products_df.groupby(['Month', 'Product']).size().unstack(), the unstack() function is applied after size() to pivot the grouped data. It takes the innermost level of the index (in this case, 'Product') and converts it into column headers, resulting in a DataFrame with 'Month' as the index and 'Product' as separate columns.

# %%
pivot=most_sold_products_df.groupby(['Month', 'Product']).size().unstack()
pivot
# Out:
# Product  AA Batteries (4-pack)  AAA Batteries (4-pack)  \
# Month
# 1                         1037                    1084
# 2                         1274                    1320
# 3                         1672                    1645
# 4                         2062                    1988
# 5                         1821                    1888
# 6                         1540                    1451
# 7                         1555                    1554
# 8                         1357                    1340
# 9                         1314                    1281
# 10                        2240                    2234
# 11                        1970                    1999
# 12                        2716                    2828
#
# Product  Lightning Charging Cable  USB-C Charging Cable  Wired Headphones
# Month
# 1                            1069                  1171              1004
# 2                            1393                  1511              1179
# ...

# %%
pivot.plot(figsize=(8,6))
# Out:
# <Axes: xlabel='Month'>

# %%
all_data.columns
# Out:
# Index(['Order ID', 'Product', 'Quantity Ordered', 'Price Each', 'Order Date',
#        'Purchase Address', 'Month', 'Sales', 'City'],
#       dtype='object')

# %%
all_data['Order ID']
# Out:
# 0         176558
# 2         176559
# 3         176560
# 4         176560
# 5         176561
#            ...
# 186845    259353
# 186846    259354
# 186847    259355
# 186848    259356
# 186849    259357
# Name: Order ID, Length: 185686, dtype: object

# %%
all_data['Order ID'].duplicated(keep=False)
# Out:
# 0         False
# 2         False
# 3          True
# 4          True
# 5         False
#           ...
# 186845    False
# 186846    False
# 186847    False
# 186848    False
# 186849    False
# Name: Order ID, Length: 185686, dtype: bool

# %%
duplicated=all_data[all_data['Order ID'].duplicated(keep=False)]
duplicated
# Out:
#        Order ID                 Product  Quantity Ordered  Price Each  \
# 3        176560            Google Phone                 1      600.00
# 4        176560        Wired Headphones                 1       11.99
# 18       176574            Google Phone                 1      600.00
# 19       176574    USB-C Charging Cable                 1       11.95
# 32       176586  AAA Batteries (4-pack)                 2        2.99
# ...         ...                     ...               ...         ...
# 186792   259303   AA Batteries (4-pack)                 1        3.84
# 186803   259314        Wired Headphones                 1       11.99
# 186804   259314  AAA Batteries (4-pack)                 2        2.99
# 186841   259350            Google Phone                 1      600.00
# 186842   259350    USB-C Charging Cable                 1       11.95
#
#             Order Date                        Purchase Address  Month   Sales  \
# ...

# %%
duplicated.groupby(['Order ID'])['Product'].apply(lambda x : ','.join(x))
# Out:
# Order ID
# 141275              USB-C Charging Cable,Wired Headphones
# 141290     Apple Airpods Headphones,AA Batteries (4-pack)
# 141365                   Vareebadd Phone,Wired Headphones
# 141384                  Google Phone,USB-C Charging Cable
# 141450            Google Phone,Bose SoundSport Headphones
#                                ...
# 319536                Macbook Pro Laptop,Wired Headphones
# 319556                      Google Phone,Wired Headphones
# 319584                            iPhone,Wired Headphones
# 319596                    iPhone,Lightning Charging Cable
# 319631    34in Ultrawide Monitor,Lightning Charging Cable
# Name: Product, Length: 6879, dtype: object

# %%
##to get df reset the index
duplicated.groupby(['Order ID'])['Product'].apply(lambda x : ','.join(x)).reset_index()
# Out:
#      Order ID                                          Product
# 0      141275            USB-C Charging Cable,Wired Headphones
# 1      141290   Apple Airpods Headphones,AA Batteries (4-pack)
# 2      141365                 Vareebadd Phone,Wired Headphones
# 3      141384                Google Phone,USB-C Charging Cable
# 4      141450          Google Phone,Bose SoundSport Headphones
# ...       ...                                              ...
# 6874   319536              Macbook Pro Laptop,Wired Headphones
# 6875   319556                    Google Phone,Wired Headphones
# 6876   319584                          iPhone,Wired Headphones
# 6877   319596                  iPhone,Lightning Charging Cable
# 6878   319631  34in Ultrawide Monitor,Lightning Charging Cable
#
# [6879 rows x 2 columns]

# %%
##rename the column
dup_products=duplicated.groupby(['Order ID'])['Product'].apply(lambda x : ','.join(x)).reset_index().rename(columns={'Product':'grouped_products'})

# %%
dup_products
# Out:
#      Order ID                                 grouped_products
# 0      141275            USB-C Charging Cable,Wired Headphones
# 1      141290   Apple Airpods Headphones,AA Batteries (4-pack)
# 2      141365                 Vareebadd Phone,Wired Headphones
# 3      141384                Google Phone,USB-C Charging Cable
# 4      141450          Google Phone,Bose SoundSport Headphones
# ...       ...                                              ...
# 6874   319536              Macbook Pro Laptop,Wired Headphones
# 6875   319556                    Google Phone,Wired Headphones
# 6876   319584                          iPhone,Wired Headphones
# 6877   319596                  iPhone,Lightning Charging Cable
# 6878   319631  34in Ultrawide Monitor,Lightning Charging Cable
#
# [6879 rows x 2 columns]

# %%
dup_products_df=duplicated.merge(dup_products, how='left', on='Order ID')

# %%
dup_products_df
# Out:
#       Order ID                 Product  Quantity Ordered  Price Each  \
# 0       176560            Google Phone                 1      600.00
# 1       176560        Wired Headphones                 1       11.99
# 2       176574            Google Phone                 1      600.00
# 3       176574    USB-C Charging Cable                 1       11.95
# 4       176586  AAA Batteries (4-pack)                 2        2.99
# ...        ...                     ...               ...         ...
# 14123   259303   AA Batteries (4-pack)                 1        3.84
# 14124   259314        Wired Headphones                 1       11.99
# 14125   259314  AAA Batteries (4-pack)                 2        2.99
# 14126   259350            Google Phone                 1      600.00
# 14127   259350    USB-C Charging Cable                 1       11.95
#
#            Order Date                        Purchase Address  Month   Sales  \
# ...

# %%
cleaned = dup_products_df.drop_duplicates(subset=['Order ID'])

# %%
cleaned.shape
# Out:
# (6879, 10)

# %%
cleaned['grouped_products'].value_counts()
# Out:
# grouped_products
# iPhone,Lightning Charging Cable                     886
# Google Phone,USB-C Charging Cable                   857
# iPhone,Wired Headphones                             361
# Vareebadd Phone,USB-C Charging Cable                312
# Google Phone,Wired Headphones                       303
#                                                    ...
# 34in Ultrawide Monitor,20in Monitor                   1
# Google Phone,Wired Headphones,Macbook Pro Laptop      1
# LG Dryer,Vareebadd Phone                              1
# 20in Monitor,34in Ultrawide Monitor                   1
# LG Washing Machine,AA Batteries (4-pack)              1
# Name: count, Length: 350, dtype: int64

# %%
cleaned['grouped_products'].value_counts().plot()
# Out:
# <Axes: xlabel='grouped_products'>

# %%
cleaned['grouped_products'].value_counts().plot.pie()
# Out:
# <Axes: ylabel='count'>

# %%
cleaned['grouped_products'].value_counts()[0:5].plot.pie()
# Out:
# <Axes: ylabel='count'>
